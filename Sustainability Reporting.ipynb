# %%
import pandas as pd
import warnings

# %%
pd.set_option('display.max_colwidth', None)  
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', 100)       
pd.set_option('display.precision', 2)
pd.options.display.max_seq_items = 1000

warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## DATASETS TO IMPORT

# %% [markdown]
# ### Shipped Order Lines

# %%
df_lines = pd.read_csv('order_lines.csv', index_col=0)
print(f"{df_lines.shape[0]:,} order lines to process")
df_lines.head()
# Out:
# 5,208 order lines to process
#                           Date Month-Year  Warehouse Code Customer Code  \
# 112    2021-01-04 00:00:00.000     1-2021         3403434    5002915-15
# 14485  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 14486  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 14487  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 14488  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
#
#        Order Number  Order Line Number   Item Code  Units   Euros
# 112        20247100                  1   963543-43    2.0  381.47
# 14485      20258239                  1  8902753-53  250.0  187.03
# 14486      20258239                  2  8308591-91  500.0  452.45
# 14487      20258239                  3  8308621-21  500.0  452.45
# 14488      20258239                  4  8022921-21  400.0  567.16

# %% [markdown]
# ### Distances

# %%
df_dist = pd.read_csv('distances.csv', index_col = 0)
df_dist['Location'] = df_dist['Customer Country'].astype(str) + ', ' + df_dist['Customer City'].astype(str)
df_dist.head()
# Out:
#       Warehouse Code          Warehouse Name Warehouse Country  \
# 19           3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 610          3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 676          3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 682          3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 1375         3403434  WAREHOUSE PARIS AREA 1            FRANCE
#
#             Warehouse City Customer Code Customer Country    Customer City  \
# 19    CHALONS-EN-CHAMPAGNE    5002915-15           FRANCE       LES ANGLES
# 610   CHALONS-EN-CHAMPAGNE    5397843-43           FRANCE     SUCY EN BRIE
# 676   CHALONS-EN-CHAMPAGNE    5340669-69          GERMANY  PEINE - WOLTORF
# 682   CHALONS-EN-CHAMPAGNE    5340672-72           FRANCE       BELLEVILLE
# 1375  CHALONS-EN-CHAMPAGNE    5029913-13           FRANCE  MOISSY-CRAMAYEL
#
#         Road  Rail  Sea  Air                  Location
# 19    765.73   0.0  0.0  0.0        FRANCE, LES ANGLES
# 610   281.49   0.0  0.0  0.0      FRANCE, SUCY EN BRIE
# 676   856.00   0.0  0.0  0.0  GERMANY, PEINE - WOLTORF
# 682    52.69   0.0  0.0  0.0        FRANCE, BELLEVILLE
# 1375  288.44   0.0  0.0  0.0   FRANCE, MOISSY-CRAMAYEL

# %% [markdown]
# ### GPS Locations

# %%
df_gps = pd.read_csv('gps_locations.csv', index_col = 0)
print("{:,} Locations".format(len(df_gps)))
df_gps.head()
# Out:
# 19 Locations
#                     Location  GPS 1  GPS 2
# 867   BULGARIA, DOLNI BOGROV  42.70  23.49
# 1087       FRANCE, AUBROMETZ  50.30   2.18
# 1153      FRANCE, BELLEVILLE  48.87   2.39
# 1371    FRANCE, CLICHY CEDEX  48.90   2.30
# 1534            FRANCE, GAEL  48.12  -2.23

# %% [markdown]
# ### UOM Conversions

# %%
df_uom = pd.read_csv('uom_conversions.csv', index_col = 0)
print("{:,} Unit of Measure Conversions".format(len(df_uom)))
df_uom.head()
# Out:
# 557 Unit of Measure Conversions
#       Item Code  Conversion Ratio
# 51    995097-97              0.02
# 100   995096-96              0.02
# 113  8949591-91              0.05
# 131   952547-47              0.04
# 276   866370-70              0.04

# %%
df_join = df_lines.copy()
COLS_JOIN = ['Item Code']
df_join = pd.merge(df_join, df_uom, on=COLS_JOIN, how='left', suffixes=('', '_y'))
df_join.drop(df_join.filter(regex='_y$').columns.tolist(),axis=1, inplace=True)
print("{:,} records".format(len(df_join)))
df_join.head()
# Out:
# 5,208 records
#                       Date Month-Year  Warehouse Code Customer Code  \
# 0  2021-01-04 00:00:00.000     1-2021         3403434    5002915-15
# 1  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 2  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 3  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 4  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
#
#    Order Number  Order Line Number   Item Code  Units   Euros  \
# 0      20247100                  1   963543-43    2.0  381.47
# 1      20258239                  1  8902753-53  250.0  187.03
# 2      20258239                  2  8308591-91  500.0  452.45
# 3      20258239                  3  8308621-21  500.0  452.45
# 4      20258239                  4  8022921-21  400.0  567.16
#
#    Conversion Ratio
# 0             56.58
# 1              0.03
# 2              0.02
# 3              0.02
# 4              0.03

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Distance + GPD Locations

# %%
df_dist = pd.merge(df_dist, df_gps, on='Location', how='left', suffixes=('', '_y'))
df_dist.drop(df_dist.filter(regex='_y$').columns.tolist(),axis=1, inplace=True)
df_dist.head()
# Out:
#    Warehouse Code          Warehouse Name Warehouse Country  \
# 0         3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 1         3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 2         3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 3         3403434  WAREHOUSE PARIS AREA 1            FRANCE
# 4         3403434  WAREHOUSE PARIS AREA 1            FRANCE
#
#          Warehouse City Customer Code Customer Country    Customer City  \
# 0  CHALONS-EN-CHAMPAGNE    5002915-15           FRANCE       LES ANGLES
# 1  CHALONS-EN-CHAMPAGNE    5397843-43           FRANCE     SUCY EN BRIE
# 2  CHALONS-EN-CHAMPAGNE    5340669-69          GERMANY  PEINE - WOLTORF
# 3  CHALONS-EN-CHAMPAGNE    5340672-72           FRANCE       BELLEVILLE
# 4  CHALONS-EN-CHAMPAGNE    5029913-13           FRANCE  MOISSY-CRAMAYEL
#
#      Road  Rail  Sea  Air                  Location  GPS 1  GPS 2
# 0  765.73   0.0  0.0  0.0        FRANCE, LES ANGLES  42.58   2.05
# 1  281.49   0.0  0.0  0.0      FRANCE, SUCY EN BRIE  48.77   2.54
# 2  856.00   0.0  0.0  0.0  GERMANY, PEINE - WOLTORF  52.30  10.31
# 3   52.69   0.0  0.0  0.0        FRANCE, BELLEVILLE  48.87   2.39
# 4  288.44   0.0  0.0  0.0   FRANCE, MOISSY-CRAMAYEL  48.62   2.60

# %% [markdown]
# ### Final Join

# %%
COLS_JOIN = ['Warehouse Code', 'Customer Code']
df_join = pd.merge(df_join, df_dist, on = COLS_JOIN, how='left', suffixes=('', '_y'))
df_join.drop(df_join.filter(regex='_y$').columns.tolist(),axis=1, inplace=True)
print("{:,} records".format(len(df_join)))
df_join.head()
# Out:
# 5,208 records
#                       Date Month-Year  Warehouse Code Customer Code  \
# 0  2021-01-04 00:00:00.000     1-2021         3403434    5002915-15
# 1  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 2  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 3  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 4  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
#
#    Order Number  Order Line Number   Item Code  Units   Euros  \
# 0      20247100                  1   963543-43    2.0  381.47
# 1      20258239                  1  8902753-53  250.0  187.03
# 2      20258239                  2  8308591-91  500.0  452.45
# 3      20258239                  3  8308621-21  500.0  452.45
# 4      20258239                  4  8022921-21  400.0  567.16
#
#    Conversion Ratio          Warehouse Name Warehouse Country  \
# 0             56.58  WAREHOUSE PARIS AREA 1            FRANCE
# 1              0.03  WAREHOUSE PARIS AREA 1            FRANCE
# 2              0.02  WAREHOUSE PARIS AREA 1            FRANCE
# 3              0.02  WAREHOUSE PARIS AREA 1            FRANCE
# 4              0.03  WAREHOUSE PARIS AREA 1            FRANCE
#
#          Warehouse City Customer Country Customer City    Road  Rail  Sea  \
# 0  CHALONS-EN-CHAMPAGNE           FRANCE    LES ANGLES  765.73   0.0  0.0
# 1  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
# 2  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
# 3  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
# 4  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
#
#    Air              Location  GPS 1  GPS 2
# 0  0.0    FRANCE, LES ANGLES  42.58   2.05
# 1  0.0  FRANCE, SUCY EN BRIE  48.77   2.54
# 2  0.0  FRANCE, SUCY EN BRIE  48.77   2.54
# 3  0.0  FRANCE, SUCY EN BRIE  48.77   2.54
# 4  0.0  FRANCE, SUCY EN BRIE  48.77   2.54

# %% [markdown]
# ## CALCULATIONS

# %% [markdown]
# ### Order Line Level

# %%
# Calculation @ line level
df_line = df_join.copy()

# Create the KG column
df_line['KG'] = df_line['Units'] * df_line['Conversion Ratio']

dict_co2e = dict(zip(['Air' ,'Sea', 'Road', 'Rail'], [2.1, 0.01, 0.096, 0.028]))
MODES = ['Road', 'Rail','Sea', 'Air']
for mode in MODES:
    df_line['CO2 ' + mode] = df_line['KG'].astype(float)/1000 * df_line[mode].astype(float) * dict_co2e[mode]
df_line['CO2 Total'] = df_line[['CO2 ' + mode for mode in MODES]].sum(axis = 1)
df_line.to_csv('detailed_report.csv')
df_line.head()
# Out:
#                       Date Month-Year  Warehouse Code Customer Code  \
# 0  2021-01-04 00:00:00.000     1-2021         3403434    5002915-15
# 1  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 2  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 3  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
# 4  2021-01-07 00:00:00.000     1-2021         3403434    5397843-43
#
#    Order Number  Order Line Number   Item Code  Units   Euros  \
# 0      20247100                  1   963543-43    2.0  381.47
# 1      20258239                  1  8902753-53  250.0  187.03
# 2      20258239                  2  8308591-91  500.0  452.45
# 3      20258239                  3  8308621-21  500.0  452.45
# 4      20258239                  4  8022921-21  400.0  567.16
#
#    Conversion Ratio          Warehouse Name Warehouse Country  \
# 0             56.58  WAREHOUSE PARIS AREA 1            FRANCE
# 1              0.03  WAREHOUSE PARIS AREA 1            FRANCE
# 2              0.02  WAREHOUSE PARIS AREA 1            FRANCE
# 3              0.02  WAREHOUSE PARIS AREA 1            FRANCE
# 4              0.03  WAREHOUSE PARIS AREA 1            FRANCE
#
#          Warehouse City Customer Country Customer City    Road  Rail  Sea  \
# 0  CHALONS-EN-CHAMPAGNE           FRANCE    LES ANGLES  765.73   0.0  0.0
# 1  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
# 2  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
# 3  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
# 4  CHALONS-EN-CHAMPAGNE           FRANCE  SUCY EN BRIE  281.49   0.0  0.0
#
#    Air              Location  GPS 1  GPS 2      KG  CO2 Road  CO2 Rail  \
# 0  0.0    FRANCE, LES ANGLES  42.58   2.05  113.17      8.32       0.0
# 1  0.0  FRANCE, SUCY EN BRIE  48.77   2.54    8.00      0.22       0.0
# 2  0.0  FRANCE, SUCY EN BRIE  48.77   2.54   11.10      0.30       0.0
# 3  0.0  FRANCE, SUCY EN BRIE  48.77   2.54   11.10      0.30       0.0
# 4  0.0  FRANCE, SUCY EN BRIE  48.77   2.54   12.80      0.35       0.0
#
#    CO2 Sea  CO2 Air  CO2 Total
# 0      0.0      0.0       8.32
# 1      0.0      0.0       0.22
# 2      0.0      0.0       0.30
# 3      0.0      0.0       0.30
# 4      0.0      0.0       0.35

# %% [markdown]
# ### Order Level

# %%
# Calculate Weight (KG)
df_join['KG'] = df_join['Units'] * df_join['Conversion Ratio']

# Agg by order
GPBY_ORDER = ['Date', 'Month-Year', 
        'Warehouse Code', 'Warehouse Name', 'Warehouse Country', 'Warehouse City',
        'Customer Code', 'Customer Country', 'Customer City','Location', 'GPS 1', 'GPS 2', 
        'Road', 'Rail', 'Sea', 'Air',
        'Order Number']
df_agg = pd.DataFrame(df_join.groupby(GPBY_ORDER)[['Units', 'KG']].sum())
df_agg.reset_index(inplace = True)
df_agg.head()
# Out:
#                       Date Month-Year  Warehouse Code          Warehouse Name  \
# 0  2021-01-04 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 1  2021-01-07 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 2  2021-01-07 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 3  2021-01-07 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 4  2021-01-08 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
#
#   Warehouse Country        Warehouse City Customer Code Customer Country  \
# 0            FRANCE  CHALONS-EN-CHAMPAGNE    5002915-15           FRANCE
# 1            FRANCE  CHALONS-EN-CHAMPAGNE    5340669-69          GERMANY
# 2            FRANCE  CHALONS-EN-CHAMPAGNE    5340672-72           FRANCE
# 3            FRANCE  CHALONS-EN-CHAMPAGNE    5397843-43           FRANCE
# 4            FRANCE  CHALONS-EN-CHAMPAGNE    5003451-51           FRANCE
#
#       Customer City                  Location  GPS 1  GPS 2    Road  Rail  \
# 0        LES ANGLES        FRANCE, LES ANGLES  42.58   2.05  765.73   0.0
# 1   PEINE - WOLTORF  GERMANY, PEINE - WOLTORF  52.30  10.31  856.00   0.0
# 2        BELLEVILLE        FRANCE, BELLEVILLE  48.87   2.39   52.69   0.0
# 3      SUCY EN BRIE      FRANCE, SUCY EN BRIE  48.77   2.54  281.49   0.0
# 4  LEVALLOIS PERRET  FRANCE, LEVALLOIS PERRET  48.89   2.29  295.17   0.0
#
#    Sea  Air  Order Number   Units       KG
# 0  0.0  0.0      20247100     2.0   113.17
# 1  0.0  0.0      20203388   153.0  2530.32
# 2  0.0  0.0      20203383   128.0  2116.87
# 3  0.0  0.0      20258239  2771.0    71.45
# 4  0.0  0.0      21000061  2125.0   111.95

# %% [markdown]
# ### CALCULATE CO2 as f(KG, Ratios)

# %%
# CO2 Emissions
dict_co2e = dict(zip(['Air' ,'Sea', 'Road', 'Rail'], [2.1, 0.01, 0.096, 0.028]))
MODES = ['Road', 'Rail','Sea', 'Air']
for mode in MODES:
    df_agg['CO2 ' + mode] = df_agg['KG'].astype(float)/1000 * df_agg[mode].astype(float) * dict_co2e[mode]
df_agg['CO2 Total'] = df_agg[['CO2 ' + mode for mode in MODES]].sum(axis = 1)
df_agg.head()
# Out:
#                       Date Month-Year  Warehouse Code          Warehouse Name  \
# 0  2021-01-04 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 1  2021-01-07 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 2  2021-01-07 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 3  2021-01-07 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
# 4  2021-01-08 00:00:00.000     1-2021         3403434  WAREHOUSE PARIS AREA 1
#
#   Warehouse Country        Warehouse City Customer Code Customer Country  \
# 0            FRANCE  CHALONS-EN-CHAMPAGNE    5002915-15           FRANCE
# 1            FRANCE  CHALONS-EN-CHAMPAGNE    5340669-69          GERMANY
# 2            FRANCE  CHALONS-EN-CHAMPAGNE    5340672-72           FRANCE
# 3            FRANCE  CHALONS-EN-CHAMPAGNE    5397843-43           FRANCE
# 4            FRANCE  CHALONS-EN-CHAMPAGNE    5003451-51           FRANCE
#
#       Customer City                  Location  GPS 1  GPS 2    Road  Rail  \
# 0        LES ANGLES        FRANCE, LES ANGLES  42.58   2.05  765.73   0.0
# 1   PEINE - WOLTORF  GERMANY, PEINE - WOLTORF  52.30  10.31  856.00   0.0
# 2        BELLEVILLE        FRANCE, BELLEVILLE  48.87   2.39   52.69   0.0
# 3      SUCY EN BRIE      FRANCE, SUCY EN BRIE  48.77   2.54  281.49   0.0
# 4  LEVALLOIS PERRET  FRANCE, LEVALLOIS PERRET  48.89   2.29  295.17   0.0
#
#    Sea  Air  Order Number   Units       KG  CO2 Road  CO2 Rail  CO2 Sea  \
# 0  0.0  0.0      20247100     2.0   113.17      8.32       0.0      0.0
# 1  0.0  0.0      20203388   153.0  2530.32    207.93       0.0      0.0
# 2  0.0  0.0      20203383   128.0  2116.87     10.71       0.0      0.0
# 3  0.0  0.0      20258239  2771.0    71.45      1.93       0.0      0.0
# 4  0.0  0.0      21000061  2125.0   111.95      3.17       0.0      0.0
#
#    CO2 Air  CO2 Total
# 0      0.0       8.32
# 1      0.0     207.93
# 2      0.0      10.71
# 3      0.0       1.93
# 4      0.0       3.17

# %% [markdown]
# ## VISUALISATION

# %%
# Mapping the delivery Mode
df_agg['Delivery Mode'] = df_agg[MODES].astype(float).apply(
    lambda t: [mode if t[mode]>0 else '-' for mode in MODES], axis = 1)
dict_map = dict(zip(df_agg['Delivery Mode'].astype(str).unique(), 
  [i.replace(", '-'",'').replace("'-'",'').replace("'",'') for i in df_agg['Delivery Mode'].astype(str).unique()]))
df_agg['Delivery Mode'] = df_agg['Delivery Mode'].astype(str).map(dict_map)
df_agg
# Out:
#                         Date Month-Year  Warehouse Code  \
# 0    2021-01-04 00:00:00.000     1-2021         3403434
# 1    2021-01-07 00:00:00.000     1-2021         3403434
# 2    2021-01-07 00:00:00.000     1-2021         3403434
# 3    2021-01-07 00:00:00.000     1-2021         3403434
# 4    2021-01-08 00:00:00.000     1-2021         3403434
# ..                       ...        ...             ...
# 286  2021-10-26 00:00:00.000    10-2021         3403434
# 287  2021-10-27 00:00:00.000    10-2021         3403434
# 288  2021-10-27 00:00:00.000    10-2021         3403434
# 289  2021-10-28 00:00:00.000    10-2021         3403434
# 290  2021-11-01 00:00:00.000    10-2021         3403434
#
#              Warehouse Name Warehouse Country        Warehouse City  \
# 0    WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 1    WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 2    WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 3    WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 4    WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# ..                      ...               ...                   ...
# 286  WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 287  WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 288  WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 289  WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
# 290  WAREHOUSE PARIS AREA 1            FRANCE  CHALONS-EN-CHAMPAGNE
#
#     Customer Code Customer Country     Customer City  \
# 0      5002915-15           FRANCE        LES ANGLES
# 1      5340669-69          GERMANY   PEINE - WOLTORF
# 2      5340672-72           FRANCE        BELLEVILLE
# 3      5397843-43           FRANCE      SUCY EN BRIE
# 4      5003451-51           FRANCE  LEVALLOIS PERRET
# ..            ...              ...               ...
# 286    5340672-72           FRANCE        BELLEVILLE
# 287    5029913-13           FRANCE   MOISSY-CRAMAYEL
# 288    5334855-55   UNITED KINGDOM              KENT
# 289    5397843-43           FRANCE      SUCY EN BRIE
# 290    5340669-69          GERMANY   PEINE - WOLTORF
#
#                      Location  GPS 1  GPS 2    Road  Rail   Sea  Air  \
# 0          FRANCE, LES ANGLES  42.58   2.05  765.73   0.0   0.0  0.0
# 1    GERMANY, PEINE - WOLTORF  52.30  10.31  856.00   0.0   0.0  0.0
# 2          FRANCE, BELLEVILLE  48.87   2.39   52.69   0.0   0.0  0.0
# 3        FRANCE, SUCY EN BRIE  48.77   2.54  281.49   0.0   0.0  0.0
# 4    FRANCE, LEVALLOIS PERRET  48.89   2.29  295.17   0.0   0.0  0.0
# ..                        ...    ...    ...     ...   ...   ...  ...
# 286        FRANCE, BELLEVILLE  48.87   2.39   52.69   0.0   0.0  0.0
# 287   FRANCE, MOISSY-CRAMAYEL  48.62   2.60  288.44   0.0   0.0  0.0
# 288      UNITED KINGDOM, KENT  51.20   0.74  409.00   0.0  44.0  0.0
# 289      FRANCE, SUCY EN BRIE  48.77   2.54  281.49   0.0   0.0  0.0
# 290  GERMANY, PEINE - WOLTORF  52.30  10.31  856.00   0.0   0.0  0.0
#
#      Order Number    Units       KG  CO2 Road  CO2 Rail  CO2 Sea  CO2 Air  \
# 0        20247100      2.0   113.17      8.32       0.0     0.00      0.0
# 1        20203388    153.0  2530.32    207.93       0.0     0.00      0.0
# 2        20203383    128.0  2116.87     10.71       0.0     0.00      0.0
# 3        20258239   2771.0    71.45      1.93       0.0     0.00      0.0
# 4        21000061   2125.0   111.95      3.17       0.0     0.00      0.0
# ..            ...      ...      ...       ...       ...      ...      ...
# 286      21004398   9040.0   416.75      2.11       0.0     0.00      0.0
# 287      21089663  13515.0   493.52     13.67       0.0     0.00      0.0
# 288      21009276    450.0    35.35      1.39       0.0     0.02      0.0
# 289      21089497  11831.0   367.71      9.94       0.0     0.00      0.0
# 290      21004473   4400.0   698.80     57.42       0.0     0.00      0.0
#
#      CO2 Total Delivery Mode
# 0         8.32        [Road]
# 1       207.93        [Road]
# 2        10.71        [Road]
# 3         1.93        [Road]
# 4         3.17        [Road]
# ..         ...           ...
# 286       2.11        [Road]
# 287      13.67        [Road]
# 288       1.40   [Road, Sea]
# 289       9.94        [Road]
# 290      57.42        [Road]
#
# [291 rows x 25 columns]

# %%
# Save Final Report
df_agg.to_csv('final_report.csv')
